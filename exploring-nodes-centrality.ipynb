# %% [markdown]
# This notebook reduces the size of our network for visualisation purposes.

# %%
import os
import re

import numpy as np
import pandas as pd

from helper import display_df_with_bokeh

pd.set_option('display.width', 1000)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>

# %%
DATASETS_FOLDER = "datasets"

# %%
# Opening original network with modularity
with open(f"gephi/dynamic/nodes_with_all_network_stats_and_timestamps.csv", 'r') as f:
    gephi_df = pd.read_csv(f, header=0)

# %%
gephi_df.head(10)
# Out:
#         Id    Label                              timeset        date last_citation  modularity_class  indegree  outdegree  Degree  Eccentricity  ...  harmonicclosnesscentrality  betweenesscentrality  eigencentrality  weighted indegree  weighted outdegree  Weighted Degree  pageranks  componentnumber  strongcompnum  clustering
# 0     1001     1001  <[946684800000.0, 1040169600000.0]>  2000-01-01    2002-12-18                42        10         83      93            12  ...                    0.239403          31325.987485         0.003194                 10                  83               93   0.000014                0           8675    0.083918
# 1  9304045  9304045  <[734482800000.0, 1030748400000.0]>  1993-04-11    2002-08-31                42        16          1      17             1  ...                    1.000000            301.901755         0.005746                 16                   1               17   0.000062                0            594    0.044118
# 2  9308122  9308122  <[746319600000.0, 1051138800000.0]>  1993-08-26    2003-04-24                42       115          7     122             1  ...                    1.000000           6156.357774         0.057921                115                   7              122   0.000259                0            587    0.057309
# 3  9309097  9309097  <[748220400000.0, 1048204800000.0]>  1993-09-17    2003-03-21                42       140          4     144             1  ...                    1.000000          11604.829042         0.077625                140                   4              144   0.001109                0            211    0.034625
# 4  9311042  9311042  <[752630400000.0, 1035327600000.0]>  1993-11-07    2002-10-23                42        55          2      57             1  ...                    1.000000            367.573730         0.036253                 55                   2               57   0.000149                0            787    0.072995
# 5  9401139  9401139  <[759628800000.0, 1051138800000.0]>  1994-01-27    2003-04-24                31       421         40     461             4  ...                    0.608025         623063.182570         0.218734                421                  40              461   0.002271                0            125    0.011525
# 6  9404151  9404151  <[767142000000.0, 1046390400000.0]>  1994-04-24    2003-02-28                42        77          2      79             4  ...                    0.442308          12546.061285         0.059789                 77                   2               79   0.000480                0            323    0.061181
# 7  9407087  9407087  <[774226800000.0, 1051657200000.0]>  1994-07-15    2003-04-30                42      1299          9    1308             5  ...                    0.427034         257938.605777         0.607171               1299                   9             1308   0.006232                0            128    0.009961
# 8  9408099  9408099  <[777078000000.0, 1051657200000.0]>  1994-08-17    2003-04-30                42      1006          7    1013             6  ...                    0.349870          39791.387146         0.448190               1006                   7             1013   0.003184                0            129    0.012014
# 9  9501030  9501030  <[789696000000.0, 1034636400000.0]>  1995-01-10    2002-10-15                31       126         27     153             6  ...                    0.391218         144397.604647         0.123279                126                  27              153   0.001160                0            370    0.065660
#
# [10 rows x 21 columns]

# %%
gephi_df[['Id', 'indegree']].sort_values(['indegree'], ascending=False)[:10]
# Out:
#           Id  indegree
# 559  9711200      2414
# 719  9802150      1775
# 718  9802109      1641
# 7    9407087      1299
# 469  9610043      1199
# 250  9510017      1155
# 589  9908142      1142
# 10   9503124      1114
# 611  9906064      1031
# 8    9408099      1006

# %%
gephi_df[['Id', 'pageranks']].sort_values(['pageranks'], ascending=False)[:10]
# Out:
#           Id  pageranks
# 7    9407087   0.006232
# 10   9503124   0.004656
# 250  9510017   0.004350
# 132  9402044   0.003900
# 559  9711200   0.003501
# 155  9410167   0.003434
# 8    9408099   0.003184
# 130  9402002   0.002980
# 469  9610043   0.002741
# 158  9205027   0.002583

# %%
gephi_df[['Id', 'eigencentrality']].sort_values(['eigencentrality'], ascending=False)[:10]
# Out:
#           Id  eigencentrality
# 559  9711200         1.000000
# 719  9802150         0.748002
# 250  9510017         0.721543
# 718  9802109         0.716547
# 10   9503124         0.693146
# 469  9610043         0.612174
# 7    9407087         0.607171
# 246  9510135         0.501494
# 155  9410167         0.498389
# 8    9408099         0.448190

# %%
gephi_df[['Id', 'closnesscentrality']].sort_values(['closnesscentrality'], ascending=False)[:10]
# Out:
#             Id  closnesscentrality
# 12143  9302088                 1.0
# 18639  9703018                 1.0
# 2787   9606079                 1.0
# 2788   9702114                 1.0
# 25376  9503008                 1.0
# 7725   9302129                 1.0
# 2795   9705154                 1.0
# 25372  9502154                 1.0
# 7706   9311014                 1.0
# 25366  9502142                 1.0

# %%
gephi_df[['Id', 'betweenesscentrality']].sort_values(['betweenesscentrality'], ascending=False)[:10]
# Out:
#             Id  betweenesscentrality
# 811    9905111          1.794420e+07
# 589    9908142          4.110736e+06
# 559    9711200          3.461610e+06
# 611    9906064          3.092353e+06
# 15567   106048          2.442442e+06
# 1613   9802067          2.435570e+06
# 1377   9908105          2.215263e+06
# 6291   9910053          2.180769e+06
# 443    9611050          1.640261e+06
# 1346   9809039          1.589239e+06
